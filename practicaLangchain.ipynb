# %%
# !pip install langchain
# !pip install langchain-community

# %%
# Importar las bibliotecas necesarias
from langchain.chat_models import ChatOpenAI  # Importar desde langchain.chat_models
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from key import key
import os

# %% [markdown]
# # La clave se importa del archivo key.py  por seguridad

# %%
# Configurar la API key de OpenAI
os.environ["OPENAI_API_KEY"] = key

# %%
# Crear el template del prompt
prompt_template = PromptTemplate(
    input_variables=["tema"],
    template="""
    Eres un experto en seguridad industrial en el sector petrolero y trabajas como blogger para una consultora.
    Crea una entrada de blog informativa y atractiva sobre un tema específico de seguridad, educando a los profesionales sobre mejores prácticas y regulaciones actuales.
    
    Tema: {tema}

    Formato de salida:
    1. Título llamativo (máximo 10 palabras)
    2. Introducción (2-3 oraciones)
    3. Cuerpo principal (3-4 párrafos)
    4. Conclusión (1-2 oraciones)
    5. Llamada a la acción

    El contenido debe:
    - Incluir estadísticas relevantes y actualizadas
    - Mencionar al menos una regulación o estándar de seguridad aplicable
    - Proporcionar consejos prácticos o mejores prácticas
    - Usar un tono profesional pero accesible
    - Incluir subtítulos para separar secciones
    - Tener una lista con viñetas para los consejos o puntos clave
    - Tener una longitud total de 400-500 palabras

    Genera la entrada de blog siguiendo estas instrucciones.
    """
)

# Crear el modelo de lenguaje
llm = ChatOpenAI(temperature=0.7, model="gpt-4")

# Crear la cadena
chain = LLMChain(llm=llm, prompt=prompt_template)

# Función para generar la entrada de blog
def generar_blog(tema):
    return chain.run(tema)

# Ejemplo de uso
tema = "Prevención de derrames de petróleo en operaciones offshore"
resultado = generar_blog(tema)
print(resultado)
# Out:
# 1. Título: "Navegando Seguro: Previniendo Derrames de Petróleo en Operaciones Offshore"
#
# 2. Introducción:
# El sector petrolero tiene enormes desafíos en cuanto a seguridad. Un error puede causar la devastación del medio ambiente, al igual que pérdidas económicas significativas. Uno de los problemas más graves son los derrames de petróleo en operaciones offshore.
#
# 3. Cuerpo principal:
#
# - **La realidad de los derrames de petróleo**
# Según el National Oceanic and Atmospheric Administration (NOAA), se han registrado más de 1,300 derrames de petróleo en aguas estadounidenses desde 2001. Estos incidentes no solo causan daños ambientales graves, sino que también pueden costar a las empresas millones en limpieza y sanciones legales.
#
# - **Regulaciones y estándares de seguridad**
# Entre las regulaciones para prevenir derrames, destaca el estándar API RP 14J de la American Petroleum Institute. Este estándar proporciona directrices para el diseño, mantenimiento y operación segura de los sistemas de perforación offshore, con el objetivo de prevenir derrames de petróleo.
#
# - **Mejores prácticas para prevenir derrames**
# Aquí hay algunos consejos clave para prevenir derrames de petróleo en operaciones offshore:
#
#     - Realizar inspecciones y mantenimiento regulares: Mantener el equipo en buen estado es crucial para prevenir derrames. Esto incluye la revisión regular de las líneas de tuberías, las válvulas y otros componentes críticos.
#     - Capacitación del personal: Asegurarse de que el personal esté debidamente capacitado en las operaciones y en el manejo de emergencias puede prevenir accidentes.
#     - Planes de emergencia: Tener un plan de respuesta a derrames bien establecido puede minimizar el daño si ocurre un derrame.
#
# 4. Conclusión:
# Prevenir los derrames de petróleo es un desafío, pero con la adhesión a las regulaciones, la implementación de las mejores prácticas y una cultura de seguridad fuerte, es posible minimizar este riesgo.
#
# 5. Llamada a la acción:
# ¿Estás listo para mejorar tus prácticas de seguridad en operaciones offshore? Contacta con nuestros expertos para obtener asesoramiento personalizado y aprender cómo puedes prevenir derrames de petróleo y mantener tus operaciones seguras y eficientes.

# %%
# Pruebas adicionales
temas_prueba = [
    "Seguridad en el manejo de gases tóxicos en refinerías",
    "Implementación de sistemas de gestión de seguridad en plataformas petroleras",
    "Nuevas tecnologías para la detección temprana de fugas en oleoductos"
]

for tema in temas_prueba:
    print(f"\n\nEntrada de blog sobre: {tema}")
    print(generar_blog(tema))
# Out:
# Entrada de blog sobre: Seguridad en el manejo de gases tóxicos en refinerías
# 1. Título: "Manejando Gases Tóxicos: Seguridad en las Refinerías Petroleras"
#
# 2. Introducción:
# En la industria petrolera, la seguridad es primordial, especialmente en el manejo de gases tóxicos en las refinerías. Este artículo proporcionará una visión actualizada y completa sobre las mejores prácticas y regulaciones existentes para garantizar un entorno laboral seguro.
#
# 3. Cuerpo principal:
#
#     Subtítulo: "Una Mirada a las Estadísticas"
# Según la Agencia de Protección Ambiental de los Estados Unidos (EPA), las refinerías petroleras emiten alrededor de 20,000 toneladas de gases tóxicos al año. Estas emisiones pueden suponer un riesgo tanto para los trabajadores como para las comunidades cercanas si no se gestionan correctamente.
#
#     Subtítulo: "Regulaciones y Estándares Actuales"
# La Administración de Seguridad y Salud Ocupacional (OSHA) establece los estándares para el manejo seguro de gases tóxicos. El estándar 29 CFR 1910.119 de la OSHA, "Proceso de Administración de Seguridad", proporciona una guía detallada sobre cómo las refinerías deben gestionar los riesgos asociados con los procesos que utilizan productos químicos altamente peligrosos, incluyendo gases tóxicos.
#
#     Subtítulo: "Mejores Prácticas para el Manejo de Gases Tóxicos"
# Aquí hay algunos consejos prácticos para el manejo seguro de gases tóxicos en refinerías:
#
# - Capacitación continua: Los trabajadores deben estar debidamente capacitados y educados sobre los riesgos asociados con los gases tóxicos y cómo manejarlos de manera segura.
# - Utilización de equipo de protección personal (EPP): El EPP adecuado, como respiradores y trajes protectores, debe ser usado en todo momento.
# - Monitoreo constante: Las áreas donde se manejan gases tóxicos deben ser monitoreadas regularmente para detectar cualquier fuga o exposición.
# - Plan de emergencia: Las refinerías deben tener un plan de emergencia en caso de una fuga de gas tóxico. Este plan debe ser conocido y practicado regularmente por todos los trabajadores.
#
# 4. Conclusión:
# En última instancia, la seguridad en el manejo de gases tóxicos en las refinerías es una responsabilidad compartida. Cada individuo, desde los operarios hasta los gerentes, debe desempeñar su papel para garantizar un entorno de trabajo seguro.
#
# 5. Llamada a la acción:
# ¿Está buscando más consejos y mejores prácticas sobre seguridad industrial en el sector petrolero? Suscríbase a nuestro blog y manténgase al tanto de las últimas tendencias y regulaciones en el campo de la seguridad industrial.
#
#
# Entrada de blog sobre: Implementación de sistemas de gestión de seguridad en plataformas petroleras
# 1. Título llamativo: "Elevando la Seguridad en Plataformas Petroleras: Implementación de Sistemas de Gestión"
#
# 2. Introducción:
# En la industria petrolera, la seguridad no es una opción, es una prioridad. La implementación de sistemas de gestión de seguridad en plataformas petroleras es un paso crucial para garantizar un entorno de trabajo seguro y eficiente.
#
# 3. Cuerpo principal:
#
#    Subtítulo: "La Importancia de la Seguridad en Plataformas Petroleras"
#
#    Según la Administración de Seguridad y Salud Ocupacional (OSHA), la industria del petróleo y el gas es una de las más peligrosas, con un índice de fatalidad siete veces mayor que el promedio de todas las industrias en los Estados Unidos. Este dato alarmante subraya la necesidad de sistemas de gestión de seguridad sólidos y efectivos.
#
#    Subtítulo: "Regulaciones y Estándares de Seguridad Actuales"
#
#    Existen diversas regulaciones y normativas que rigen la seguridad en las plataformas petroleras, como las normas de OSHA y la norma API RP 75 de la American Petroleum Institute (API). Esta última establece un marco para la implementación de sistemas de gestión de seguridad, incluyendo la identificación de peligros, la gestión de riesgos y la preparación para emergencias.
#
#    Subtítulo: "Implementación de Sistemas de Gestión de Seguridad"
#
#    La implementación de un sistema de gestión de seguridad es un proceso que requiere planificación y compromiso. Aquí hay algunos consejos para hacerlo de manera efectiva:
#
#    - Realice una evaluación de riesgos completa: Identifique todos los posibles peligros y evalúe su nivel de riesgo.
#    - Desarrolle procedimientos de control de riesgos: Esto puede incluir protocolos de trabajo seguro, programas de mantenimiento y sistemas de detección de peligros.
#    - Proporcione formación y educación: Asegúrese de que todos los empleados entiendan el sistema de gestión de seguridad y cómo contribuir a él.
#    - Realice auditorías y revisiones regulares: Esto ayudará a identificar áreas de mejora y asegurar que el sistema esté funcionando como se esperaba.
#
# 4. Conclusión:
#
#    La implementación de sistemas de gestión de seguridad en plataformas petroleras es esencial para proteger a los trabajadores y mantener la eficiencia operativa. Con la planificación y el compromiso adecuados, estos sistemas pueden marcar una diferencia significativa en la seguridad general de la plataforma.
#
# 5. Llamada a acción:
#
#    ¿Está listo para mejorar la seguridad en su plataforma petrolera? Póngase en contacto con nosotros hoy mismo para obtener más información sobre cómo podemos ayudarle a implementar un sistema de gestión de seguridad efectivo.
#
#
# Entrada de blog sobre: Nuevas tecnologías para la detección temprana de fugas en oleoductos
# Título: "Innovación en la detección temprana de fugas en oleoductos: Un paso adelante en seguridad industrial"
#
# Introducción:
# La detección temprana de fugas en oleoductos es esencial para garantizar la seguridad en la industria petrolera. Con la adopción de nuevas tecnologías, es posible prevenir accidentes, minimizar riesgos y cumplir con las regulaciones actuales.
#
# Cuerpo principal:
#
# **Impacto y relevancia de las fugas de oleoductos**
#
# Según la Pipeline and Hazardous Materials Safety Administration (PHMSA), solo en Estados Unidos, se registraron 633 incidentes relacionados con oleoductos en 2019, resultando en daños económicos y ambientales significativos. La detección temprana de fugas es crucial para minimizar estos impactos y garantizar el cumplimiento de las normativas como la ASME B31.8 que establece los estándares de seguridad para los sistemas de tuberías de gas.
#
# **Nuevas tecnologías en la detección de fugas**
#
# La detección de fugas ha evolucionado significativamente gracias a la incorporación de tecnologías avanzadas como sensores de fibra óptica, drones y sistemas de inteligencia artificial. Estos sistemas pueden identificar anomalías y alertar a los operadores en tiempo real, permitiendo una respuesta más rápida y eficaz.
#
# Los sensores de fibra óptica, por ejemplo, pueden detectar cambios en la temperatura, vibración y presión a lo largo del oleoducto. Los drones equipados con cámaras térmicas e infrarrojas pueden inspeccionar grandes áreas en poco tiempo, identificando fugas que podrían pasar desapercibidas en una inspección terrestre.
#
# La inteligencia artificial, por su parte, puede procesar y analizar grandes volúmenes de datos de estos sensores y drones para detectar fugas con mayor precisión y reducir falsas alarmas.
#
# **Mejores prácticas en la detección de fugas**
#
# Aquí hay algunos consejos para implementar estas tecnologías de manera efectiva:
#
# - Realizar una evaluación de riesgos antes de seleccionar y desplegar una tecnología de detección de fugas.
# - Asegurarse de que el personal esté adecuadamente capacitado en el uso y mantenimiento de la tecnología seleccionada.
# - Combinar diferentes tecnologías para cubrir una gama más amplia de posibles escenarios de fuga.
# - Integrar los sistemas de detección de fugas con otros sistemas de gestión de seguridad y respuesta a emergencias.
#
# Conclusión:
#
# La adopción de nuevas tecnologías para la detección temprana de fugas en oleoductos es un paso significativo hacia una industria petrolera más segura y sostenible. Sin embargo, es fundamental recordar que estas tecnologías son herramientas que deben ser manejadas por profesionales capacitados y dentro de un marco de gestión de seguridad integral.
#
# Llamada a la acción:
#
# ¿Estás interesado en saber más sobre cómo estas nuevas tecnologías pueden mejorar la seguridad de tu empresa? Contacta con nosotros para obtener más información y asegúrate de que tu operación esté al día con las últimas innovaciones en seguridad industrial.
